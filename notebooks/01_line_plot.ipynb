# %% [markdown]
# # 🧩 Notebook-01: Line Plot with Matplotlib

# %%
# Setup & Imports
import pandas as pd
import matplotlib.pyplot as plt
import sys
from pathlib import Path

# ✅ Setup path to use utils
PROJECT_ROOT = Path.cwd().parent
UTILS_DIR = PROJECT_ROOT / "utils"
if str(UTILS_DIR) not in sys.path:
    sys.path.insert(0, str(UTILS_DIR))

from plot_utils import line_plot, multi_line_plot

print("📈 Line Plots using Matplotlib\n")
# Out:
# 📈 Line Plots using Matplotlib

# %%
# Load Dataset
df = pd.read_csv(PROJECT_ROOT / "datasets" / "sales_data.csv")
df.head()
# Out:
#      Month     Product  Units Sold  Revenue
# 0  2023-01      Laptop         152   176320
# 1  2023-01      Tablet          64    91520
# 2  2023-01  Smartphone         121   162624
# 3  2023-01     Monitor         152    63992
# 4  2023-02      Laptop         124    47988

# %%
# Single Line Plot – Total Units Sold Over Time
df_grouped = df.groupby("Month")["Units Sold"].sum().reset_index()

line_plot(
    x=df_grouped["Month"],
    y=df_grouped["Units Sold"],
    title="📈 Total Monthly Units Sold (All Products)",
    xlabel="Month",
    ylabel="Units Sold",
    label="All Products",
    color="blue",
    marker="o"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:22: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/satvikpraveen/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Multi-Line Plot – Product-Wise Sales Trend

df_pivot = df.pivot(index="Month", columns="Product", values="Units Sold").reset_index()
df_pivot.head()

multi_line_plot(
    df=df_pivot,
    x_col="Month",
    y_cols=["Laptop", "Tablet", "Smartphone", "Monitor"],
    labels=["Laptop", "Tablet", "Smartphone", "Monitor"],
    colors=["blue", "green", "red", "orange"],
    markers=["o", "s", "^", "D"],
    title="📊 Product-Wise Monthly Units Sold",
    xlabel="Month",
    ylabel="Units Sold"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:47: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/satvikpraveen/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Line Styles & Customization
line_plot(
    x=df_grouped["Month"],
    y=df_grouped["Units Sold"],
    title="Dashed Line with Triangle Markers",
    xlabel="Month",
    ylabel="Units Sold",
    label="Total Sales",
    color="purple",
    linestyle="--",
    marker="^"
)

# %% [markdown]
# ## ✅ Summary
# - ✅ Created reusable plot functions in `plot_utils.py`
# - ✅ Applied single-line and multi-line plotting
# - ✅ Demonstrated custom styling with color, marker, and linestyle
