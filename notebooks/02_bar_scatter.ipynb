# %% [markdown]
# # 🧩 Notebook-02: Bar and Scatter Plots with Matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
from pathlib import Path

# ✅ Setup path to use utils
PROJECT_ROOT = Path.cwd().parent
UTILS_DIR = PROJECT_ROOT / "utils"
if str(UTILS_DIR) not in sys.path:
    sys.path.insert(0, str(UTILS_DIR))

from plot_utils import bar_plot, grouped_bar_plot, scatter_plot

print("📊 Bar and Scatter Plots using Matplotlib\n")
# Out:
# 📊 Bar and Scatter Plots using Matplotlib

# %%
# 🗂️ 1. Load Dataset
df = pd.read_csv(PROJECT_ROOT / "datasets" / "sales_data.csv")
df.head()
# Out:
#      Month     Product  Units Sold  Revenue
# 0  2023-01      Laptop         152   176320
# 1  2023-01      Tablet          64    91520
# 2  2023-01  Smartphone         121   162624
# 3  2023-01     Monitor         152    63992
# 4  2023-02      Laptop         124    47988

# %%
# 📦 2. Vertical Bar Plot – Total Units Sold per Product
product_totals = df.groupby("Product")["Units Sold"].sum().reset_index()

bar_plot(
    categories=product_totals["Product"],
    values=product_totals["Units Sold"],
    title="📦 Total Units Sold per Product",
    xlabel="Product",
    ylabel="Units Sold"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:79: UserWarning: Glyph 128230 (\N{PACKAGE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/satvikpraveen/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128230 (\N{PACKAGE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 📊 3. Horizontal Bar Plot – Revenue per Product
revenue_totals = df.groupby("Product")["Revenue"].sum().reset_index()

bar_plot(
    categories=revenue_totals["Product"],
    values=revenue_totals["Revenue"],
    horizontal=True,
    title="💰 Total Revenue per Product",
    xlabel="Revenue ($)",
    ylabel="Product",
    color="salmon"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:79: UserWarning: Glyph 128176 (\N{MONEY BAG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/satvikpraveen/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128176 (\N{MONEY BAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 🪄 4. Grouped Bar Plot – Product-Wise Sales Over Months
df_grouped = df.groupby(["Month", "Product"])["Units Sold"].sum().unstack().reset_index()
data_dict = {
    product: df_grouped[product].tolist() for product in df_grouped.columns[1:]
}

grouped_bar_plot(
    x_labels=df_grouped["Month"].tolist(),
    data_dict=data_dict,
    title="📊 Monthly Units Sold by Product",
    xlabel="Month",
    ylabel="Units Sold"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:109: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/satvikpraveen/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 🎯 5. Scatter Plot – Units Sold vs Revenue
scatter_plot(
    x=df["Units Sold"],
    y=df["Revenue"],
    title="🔍 Revenue vs. Units Sold",
    xlabel="Units Sold",
    ylabel="Revenue"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:136: UserWarning: Glyph 128269 (\N{LEFT-POINTING MAGNIFYING GLASS}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/satvikpraveen/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128269 (\N{LEFT-POINTING MAGNIFYING GLASS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 🎨 6. Advanced Scatter – Color + Size Mapping
df["ColorMap"] = df["Units Sold"]
df["BubbleSize"] = np.sqrt(df["Revenue"])

scatter_plot(
    x=df["Units Sold"],
    y=df["Revenue"],
    color_values=df["ColorMap"],
    size=df["BubbleSize"],
    cmap="viridis",
    title="🧠 Revenue vs. Units Sold (Colored & Scaled)",
    xlabel="Units Sold",
    ylabel="Revenue",
    use_colorbar=True,
    edgecolor="black"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:136: UserWarning: Glyph 129504 (\N{BRAIN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/satvikpraveen/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 129504 (\N{BRAIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## ✅ Summary
# - ✅ Used reusable `bar_plot()`, `grouped_bar_plot()`, and `scatter_plot()` functions
# - ✅ Built vertical, horizontal, and grouped bars
# - ✅ Created bubble scatter plots with size & colormap
