# %% [markdown]
# # 🧩 Notebook-03: Histograms and Pie Charts with Matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
from pathlib import Path

# ✅ Setup path to use utils
PROJECT_ROOT = Path.cwd().parent
UTILS_DIR = PROJECT_ROOT / "utils"
if str(UTILS_DIR) not in sys.path:
    sys.path.insert(0, str(UTILS_DIR))

from plot_utils import histogram_plot, pie_chart

print("📊 Histograms and Pie Charts using Matplotlib\n")
# Out:
# 📊 Histograms and Pie Charts using Matplotlib

# %%
# 🗂️ 1. Load Dataset
df = pd.read_csv(PROJECT_ROOT / "datasets" / "sales_data.csv")
df.head()
# Out:
#      Month     Product  Units Sold  Revenue
# 0  2023-01      Laptop         152   176320
# 1  2023-01      Tablet          64    91520
# 2  2023-01  Smartphone         121   162624
# 3  2023-01     Monitor         152    63992
# 4  2023-02      Laptop         124    47988

# %%
# 📈 2. Histogram – Distribution of Units Sold
histogram_plot(
    data=df["Units Sold"],
    bins=10,
    color="skyblue",
    edgecolor="black",
    title="📈 Distribution of Units Sold",
    xlabel="Units Sold",
    ylabel="Frequency"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:155: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/satvikpraveen/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 📊 3. Histogram – Revenue Distribution with Density
histogram_plot(
    data=df["Revenue"],
    bins=15,
    color="orange",
    edgecolor="white",
    alpha=0.8,
    density=True,
    title="💰 Revenue Distribution (Density)",
    xlabel="Revenue"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:155: UserWarning: Glyph 128176 (\N{MONEY BAG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/satvikpraveen/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128176 (\N{MONEY BAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 🥧 4. Pie Chart – Product Sales Proportion
product_totals = df.groupby("Product")["Units Sold"].sum().reset_index()

pie_chart(
    labels=product_totals["Product"],
    values=product_totals["Units Sold"],
    colors=["#66b3ff", "#99ff99", "#ffcc99", "#ff9999"],
    explode=[0.05]*4,
    title="🥧 Units Sold Share by Product"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:178: UserWarning: Glyph 129383 (\N{PIE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/satvikpraveen/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 129383 (\N{PIE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 💰 5. Pie Chart – Revenue Proportion by Product
revenue_totals = df.groupby("Product")["Revenue"].sum().reset_index()

pie_chart(
    labels=revenue_totals["Product"],
    values=revenue_totals["Revenue"],
    colors=["#8ecae6", "#219ebc", "#ffb703", "#fb8500"],
    explode=[0.05]*4,
    title="💰 Revenue Share by Product"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:178: UserWarning: Glyph 128176 (\N{MONEY BAG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/satvikpraveen/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128176 (\N{MONEY BAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## ✅ Summary
# - ✅ Used `histogram_plot()` for frequency and density plots
# - ✅ Visualized revenue and unit distribution with bins
# - ✅ Created styled pie charts for proportion analysis
# - ✅ Introduced explode, custom colors, and shadows
