# %% [markdown]
# # 🧩 Notebook-05: Customization and Styling with Matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
from pathlib import Path

# ✅ Setup path to use utils
PROJECT_ROOT = Path.cwd().parent
UTILS_DIR = PROJECT_ROOT / "utils"
if str(UTILS_DIR) not in sys.path:
    sys.path.insert(0, str(UTILS_DIR))

from plot_utils import line_plot
from theme_utils import apply_dark_theme, apply_corporate_theme, apply_minimal_theme, reset_theme

print("🎨 Customization and Styling in Matplotlib\n")
# Out:
# 🎨 Customization and Styling in Matplotlib

# %%
# 🗂️ 1. Load Dataset

df = pd.read_csv(PROJECT_ROOT / "datasets" / "sales_data.csv")
monthly = df.groupby("Month")["Units Sold"].sum().reset_index()

# %%
# 🎨 2. Default Theme (Baseline)

reset_theme()

line_plot(
    x=monthly["Month"],
    y=monthly["Units Sold"],
    title="🧪 Default Theme: Units Sold",
    xlabel="Month",
    ylabel="Units Sold",
    label="Units Sold",
    color="mediumblue",
    marker="o"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:23: UserWarning: Glyph 129514 (\N{TEST TUBE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/satvikpraveen/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 129514 (\N{TEST TUBE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 🖤 3. Dark Theme
apply_dark_theme()

line_plot(
    x=monthly["Month"],
    y=monthly["Units Sold"],
    title="🌙 Dark Theme: Units Sold",
    xlabel="Month",
    ylabel="Units Sold",
    label="Units Sold",
    color="cyan",
    marker="D"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:23: UserWarning: Glyph 127769 (\N{CRESCENT MOON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/satvikpraveen/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 127769 (\N{CRESCENT MOON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 🧑‍💼 4. Corporate Theme
apply_corporate_theme()

line_plot(
    x=monthly["Month"],
    y=monthly["Units Sold"],
    title="🏢 Corporate Theme: Units Sold",
    xlabel="Month",
    ylabel="Units Sold",
    label="Units Sold",
    color="#0077b6",
    marker="s"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:23: UserWarning: Glyph 127970 (\N{OFFICE BUILDING}) missing from font(s) Arial.
#   plt.tight_layout()
# /Users/satvikpraveen/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 127970 (\N{OFFICE BUILDING}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# ✨ 5. Minimal Theme
apply_minimal_theme()

line_plot(
    x=monthly["Month"],
    y=monthly["Units Sold"],
    title="🧼 Minimal Theme: Units Sold",
    xlabel="Month",
    ylabel="Units Sold",
    label="Units Sold",
    color="indigo",
    marker="^"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:23: UserWarning: Glyph 129532 (\N{BAR OF SOAP}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/satvikpraveen/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 129532 (\N{BAR OF SOAP}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## ✅ Summary
# - ✅ Applied 4 custom themes using rcParams: dark, corporate, minimal, and reset
# - ✅ Encapsulated themes inside `theme_utils.py`
# - ✅ Custom styling improves readability, aesthetics, and presentation
