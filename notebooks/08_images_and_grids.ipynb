# %% [markdown]
# # 🧩 Notebook-08: Images and Grids with Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys
from pathlib import Path

# ✅ Setup path to use utils
PROJECT_ROOT = Path.cwd().parent
UTILS_DIR = PROJECT_ROOT / "utils"
if str(UTILS_DIR) not in sys.path:
    sys.path.insert(0, str(UTILS_DIR))

from plot_utils import imshow_matrix, plot_image, grid_heatmap

print("🖼️ Image and Grid Visualization in Matplotlib\n")
# Out:
# 🖼️ Image and Grid Visualization in Matplotlib

# %%
# 1. Matrix Visualization – Simulated Confusion Matrix
# Simulate a confusion matrix
conf_matrix = np.array([
    [42, 2, 3],
    [4, 35, 1],
    [2, 5, 41]
])
class_labels = ['Class A', 'Class B', 'Class C']

imshow_matrix(
    matrix=conf_matrix,
    cmap='Blues',
    title="🧪 Simulated Confusion Matrix",
    xlabel="Predicted",
    ylabel="Actual"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:384: UserWarning: Glyph 129514 (\N{TEST TUBE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/satvikpraveen/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 129514 (\N{TEST TUBE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 🔥 2. Grid Heatmap – Annotated Weather Map
# Simulate city-level temperatures
data = np.random.uniform(15, 40, (4, 6)).round(1)
cities = ['Austin', 'Chicago', 'NYC', 'San Francisco']
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']

grid_heatmap(
    data=data,
    row_labels=cities,
    col_labels=months,
    cmap="Oranges",
    annot=True,
    fmt=".1f",
    title="🔥 Simulated City Temperature Grid (°C)"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:428: UserWarning: Glyph 128293 (\N{FIRE}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /Users/satvikpraveen/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128293 (\N{FIRE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 🖼️ 3. Image Display – Load Local Image (if available)
from matplotlib.image import imread
import os

# Optional local image test (skip if not available)
img_path = PROJECT_ROOT / "datasets" / "sample_image.png"

if img_path.exists():
    image = imread(img_path)
    plot_image(
        image_array=image,
        title="🖼️ Sample Image Display"
    )
else:
    print("ℹ️ sample_image.jpg not found in datasets/. Skipping image display.")
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:397: UserWarning: Glyph 128444 (\N{FRAME WITH PICTURE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/satvikpraveen/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128444 (\N{FRAME WITH PICTURE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## ✅ Summary
# - ✅ Visualized raw matrices using `imshow_matrix()`
# - ✅ Created a labeled heatmap with annotations using `grid_heatmap()`
# - ✅ Demonstrated how to display real RGB images using `plot_image()`
