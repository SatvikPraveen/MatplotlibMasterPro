# %% [markdown]
# # 🧩 Notebook-10: Exporting and Styling Plots in Matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
from pathlib import Path

# ✅ Setup path to use utils
PROJECT_ROOT = Path.cwd().parent
UTILS_DIR = PROJECT_ROOT / "utils"
if str(UTILS_DIR) not in sys.path:
    sys.path.insert(0, str(UTILS_DIR))

from plot_utils import save_plot, set_global_style

print("🖼️ Exporting & Styling with Matplotlib\n")
# Out:
# 🖼️ Exporting & Styling with Matplotlib

# %%
# 🎨 1. Set Global Style
set_global_style(style_name="seaborn-v0_8-whitegrid", font="DejaVu Sans", size=12)
# Out:
# 🎨 Global style set: 'seaborn-v0_8-whitegrid' with font 'DejaVu Sans' and size 12

# %%
# 📊 2. Load Data
df = pd.read_csv(PROJECT_ROOT / "datasets" / "sales_data.csv")
monthly = df.groupby("Month")[["Units Sold", "Revenue"]].sum().reset_index()

# %%
# 📈 3. Generate Plot with Style
fig, ax = plt.subplots(figsize=(10, 5))
x = monthly["Month"]
y = monthly["Revenue"]

ax.plot(x, y, marker="o", color="purple")
ax.set_title("🖼️ Monthly Revenue", fontsize=14)
ax.set_xlabel("Month")
ax.set_ylabel("Revenue ($)")
ax.tick_params(axis="x", rotation=45)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/23/phyj43kx4jz5gywlx6__9_kc0000gn/T/ipykernel_29289/3179361182.py:12: UserWarning: Glyph 128444 (\N{FRAME WITH PICTURE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/mp_py_env/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128444 (\N{FRAME WITH PICTURE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 💾 4. Save Plot in Multiple Formats
save_plot(fig, filename="monthly_revenue", folder=PROJECT_ROOT / "exports")
# Out:
# ✅ Plot saved as ('png', 'pdf', 'svg') in '/Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/exports/'
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:482: UserWarning: Glyph 128444 (\N{FRAME WITH PICTURE}) missing from font(s) DejaVu Sans.
#   fig.savefig(path, format=fmt, bbox_inches='tight')
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:482: UserWarning: Glyph 128444 (\N{FRAME WITH PICTURE}) missing from font(s) DejaVu Sans.
#   fig.savefig(path, format=fmt, bbox_inches='tight')

# %% [markdown]
# ## ✅ Summary
# - 🎨 Applied a clean `seaborn-whitegrid` global style
# - 🔤 Customized font and size across all plots
# - 💾 Saved the plot to PNG, PDF, and SVG formats using `save_plot()`
# - 📁 All files exported neatly into the `exports/` folder
