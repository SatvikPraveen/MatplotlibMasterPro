# %% [markdown]
# # 🧩 Notebook-11: Animated Line Plots

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
from pathlib import Path

# ✅ Setup path to use utils
PROJECT_ROOT = Path.cwd().parent
UTILS_DIR = PROJECT_ROOT / "utils"
if str(UTILS_DIR) not in sys.path:
    sys.path.insert(0, str(UTILS_DIR))

from plot_utils import animate_line_plot

print("🎞️ Animated Line Plots using Matplotlib Animation")
# Out:
# 🎞️ Animated Line Plots using Matplotlib Animation

# %%
# 📂 1. Load and Prepare Data
df = pd.read_csv(PROJECT_ROOT / "datasets" / "sales_data.csv")
monthly = df.groupby("Month")[["Units Sold", "Revenue"]].sum().reset_index()

x = monthly["Month"]
y = monthly["Revenue"]

# %%
# 📈 2. Create Animation – Monthly Revenue Growth
animate_line_plot(
    x=np.arange(len(x)),
    y=y.values,
    xlabel="Month Index",
    ylabel="Revenue",
    title="📈 Revenue Growth Over Time (Animated)",
    interval=400,
    color="green"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:528: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   ani = animation.FuncAnimation(
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/mp_py_env/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 🔁 3. Animate Dual Line Plot
from plot_utils import animate_dual_line_plot

animate_dual_line_plot(
    x=monthly["Month"],
    y1=monthly["Units Sold"],
    y2=monthly["Revenue"],
    xlabel="Month",
    ylabel="Value",
    labels=("Units Sold", "Revenue"),
    title="🔁 Animate Units Sold and Revenue"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/mp_py_env/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/mp_py_env/lib/python3.11/site-packages/matplotlib/animation.py:908: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you output the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(

# %%
# 📊 3. Animated Bar Chart
from plot_utils import animate_bar_chart

product = df.groupby("Product")["Revenue"].sum().sort_values()
animate_bar_chart(
    categories=product.index.tolist(),
    values=product.values.tolist(),
    xlabel="Product",
    ylabel="Revenue",
    title="📊 Animated Product-wise Revenue"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/mp_py_env/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/mp_py_env/lib/python3.11/site-packages/matplotlib/animation.py:908: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you output the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(

# %%
# 🔵 4. Animated Scatter Growth
from plot_utils import animate_scatter_growth

animate_scatter_growth(
    x=df["Units Sold"],
    y=df["Revenue"],
    xlabel="Units Sold",
    ylabel="Revenue",
    title="🔵 Revenue vs Units Sold Growth"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/mp_py_env/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128309 (\N{LARGE BLUE CIRCLE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 📦 5. Export Animations as .mp4

from plot_utils import (
    save_line_animation,
    save_dual_line_animation,
    save_bar_animation,
    save_scatter_animation
)

# 🔃 Export: Single Line Plot
save_line_animation(
    x=np.arange(len(x)),
    y=y.values,
    filename="../exports/revenue_growth.mp4"
)

# 🔁 Export: Dual Line Plot
save_dual_line_animation(
    x=np.arange(len(monthly["Month"])),
    y1=monthly["Units Sold"].values,
    y2=monthly["Revenue"].values,
    labels=("Units Sold", "Revenue"),
    filename="../exports/units_revenue_growth.mp4"
)

# 📊 Export: Bar Chart Animation
save_bar_animation(
    categories=product.index.tolist(),
    values=product.values.tolist(),
    filename="../exports/product_revenue_bars.mp4"
)

# 🔵 Export: Scatter Animation
save_scatter_animation(
    x=df["Units Sold"].values,
    y=df["Revenue"].values,
    filename="../exports/revenue_vs_units_scatter.mp4"
)
# Out:
# ✅ Saved line animation to: ../exports/revenue_growth.mp4
# ✅ Saved dual-line animation to: ../exports/units_revenue_growth.mp4
# ✅ Saved bar animation to: ../exports/product_revenue_bars.mp4
# ✅ Saved scatter animation to: ../exports/revenue_vs_units_scatter.mp4

# %% [markdown]
# ## ✅ Summary
# - ✅ Created animated line plot using FuncAnimation
# - ✅ Used animate_line_plot() for cleaner abstraction
# - ✅ Perfect for demos, presentations, and storytelling
