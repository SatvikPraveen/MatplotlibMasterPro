# %% [markdown]
# # 🧩 Notebook-12: Stats & Distribution Plots

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
from pathlib import Path

# ✅ Setup path to use utils
PROJECT_ROOT = Path.cwd().parent
UTILS_DIR = PROJECT_ROOT / "utils"
if str(UTILS_DIR) not in sys.path:
    sys.path.insert(0, str(UTILS_DIR))

from plot_utils import (
    plot_histogram_with_stats,
    plot_boxplot,
    plot_violinplot
)

print("📈 Statistical & Distribution Plots with Matplotlib\n")
# Out:
# 📈 Statistical & Distribution Plots with Matplotlib

# %%
# 📂 1. Load and Prepare Data
df = pd.read_csv(PROJECT_ROOT / "datasets" / "sales_data.csv")
monthly = df.groupby("Month")[["Units Sold", "Revenue"]].sum().reset_index()

units = monthly["Units Sold"]
revenue = monthly["Revenue"]

# 📊 2. Histogram with Mean, Median, Std
plot_histogram_with_stats(
    data=units,
    bins=10,
    title="📊 Distribution of Units Sold",
    xlabel="Units Sold"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:701: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/mp_py_env/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 📦 3. Boxplot of Units vs Revenue
plot_boxplot(
    data_dict={"Units Sold": units, "Revenue": revenue},
    title="📦 Boxplot: Units Sold vs Revenue",
    ylabel="Values"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:711: UserWarning: Glyph 128230 (\N{PACKAGE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/mp_py_env/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128230 (\N{PACKAGE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 🎻 4. Violin Plot (Optional but Beautiful!)
plot_violinplot(
    data_dict={"Units Sold": units, "Revenue": revenue},
    title="🎻 Violin Plot: Units Sold vs Revenue",
    ylabel="Values"
)
# Out:
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/utils/plot_utils.py:721: UserWarning: Glyph 127931 (\N{VIOLIN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/mp_py_env/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 127931 (\N{VIOLIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 📈 5. KDE-style Line Plot (Bonus!)
plt.figure(figsize=(8, 4))
units_sorted = np.sort(units)
density = np.exp(-0.5 * ((units_sorted - np.mean(units_sorted)) / np.std(units_sorted)) ** 2)
density = density / (np.std(units_sorted) * np.sqrt(2 * np.pi))
plt.plot(units_sorted, density, label="Estimated KDE", color="purple")
plt.title("📈 KDE-style Plot for Units Sold")
plt.xlabel("Units Sold")
plt.ylabel("Density")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# /var/folders/23/phyj43kx4jz5gywlx6__9_kc0000gn/T/ipykernel_31606/2724032459.py:11: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/satvikpraveen/Desktop/Libraries/MatplotlibMasterPro/mp_py_env/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## ✅ Summary Recap:
# - ✅ Used plot_histogram_with_stats() to show stats
# - ✅ Boxplot & violin plot with labeled comparison
# - ✅ Added KDE-style plot for distribution flavor
